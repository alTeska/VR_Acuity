# %% [markdown]
# # Visualization of velocity for video-confimed events

# %%
# data loading
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from scipy import stats, integrate

# %matplotlib inline
sns.set(color_codes=True)

path = '../datasets/preprocessed/'
dfrat     = pd.read_hdf(path+'relationalDatabase.h5', 'Rat_Behavior').set_index('index')
dfevent   = pd.read_hdf(path+'relationalDatabase.h5', 'Events').set_index('index')
dfsession = pd.read_hdf(path+'relationalDatabase.h5', 'Sessions')

dfratclean = pd.read_hdf(path+'filteredDatabase.h5', 'Rat_Behavior').set_index('index')
dfratv = pd.read_hdf(path+'velocityDatabase.h5', 'Rat_Behavior').set_index('index')

# %%
dfratv.head()
# Out:
#        Frame      Time     X_Pos     Y_Pos     Z_Pos     X_Ori     Y_Ori  \
# index
# 1        655  2.729167  0.002050  0.100554  0.037935 -0.158835 -0.154542
# 2        656  2.733334  0.003672  0.100841  0.038550 -0.143174 -0.150851
# 3        657  2.737500  0.005299  0.101125  0.039161 -0.127507 -0.147160
# 4        658  2.741667  0.006931  0.101406  0.039767 -0.111809 -0.143439
# 5        659  2.745834  0.008570  0.101685  0.040368 -0.096066 -0.139570
#
#           Z_Ori  session_id        dT         lVo       lx1       lz1  \
# index
# 1      0.658703           0  0.004167  236.260012 -0.234414  0.972137
# 2      0.657018           0  0.004167  236.260012 -0.212918  0.977070
# 3      0.655308           0  0.004166  236.260012 -0.190994  0.981591
# 4      0.653580           0  0.004167  236.260012 -0.168622  0.985681
# 5      0.651787           0  0.004167  236.260012 -0.145813  0.989312
#
#              V1       lx2       lz2  clockwise     theta           U  UM
# index
# 1      0.002868 -0.255573  0.966790          1  0.021824  300.078558 NaN
# 2      0.002846 -0.234414  0.972137          1  0.022055  303.256384 NaN
# 3      0.002826 -0.212918  0.977070          1  0.022386  307.883196 NaN
# 4      0.002807 -0.190994  0.981591          1  0.022743  312.714658 NaN
# 5      0.002789 -0.168622  0.985681          1  0.023097  317.578633 NaN

# %%
dfsession
# Out:
#    index session_id rat_id                        date  \
# 0      0          0  VR-5A  2017-07-13 05.09.09.088 PM
# 1      0          1  VR-3A  2017-07-13 04.11.56.036 PM
# 2      0          2  VR-3A  2017-07-13 04.27.09.355 PM
# 3      0          3  VR-4A  2017-07-13 02.39.20.315 PM
# 4      0          4  VR-2A  2017-07-13 03.19.28.235 PM
# 5      0          5  VR-1B  2017-07-13 03.53.42.156 PM
# 6      0          6  VR-2B  2017-07-13 03.05.18.468 PM
# 7      0          7  VR-1A  2017-07-13 03.38.35.628 PM
#
#                experimenter                              original_name  \
# 0    Nicholas A. Del Grosso  VRAcuityExp_2017-07-13_17-09-07_VR-5A_NIC
# 1    Nicholas A. Del Grosso  VRAcuityExp_2017-07-13_16-11-46_VR-3A_NIC
# 2    Nicholas A. Del Grosso  VRAcuityExp_2017-07-13_16-27-08_VR-3A_NIC
# 3    Nicholas A. Del Grosso  VRAcuityExp_2017-07-13_14-39-17_VR-4A_NIC
# 4  Eduardo Blanco-Hernandez  VRAcuityExp_2017-07-13_15-19-09_VR-2A_EDU
# 5    Nicholas A. Del Grosso  VRAcuityExp_2017-07-13_15-53-40_VR-1B_NIC
# 6    Nicholas A. Del Grosso  VRAcuityExp_2017-07-13_15-05-16_VR-2B_NIC
# 7    Nicholas A. Del Grosso  VRAcuityExp_2017-07-13_15-38-34_VR-1A_NIC
#
#                                           video_name                VRspeed
# 0  VRAcuityExp_2017-07-13_17-09-07_VR-5A_NIC-Came...  [  0.   7.  14.  28.]
# 1  VRAcuityExp_2017-07-13_16-11-46_VR-3A_NIC-Came...  [  0.   7.  14.  28.]
# 2  VRAcuityExp_2017-07-13_16-27-08_VR-3A_NIC-Came...  [  0.   7.  14.  28.]
# 3  VRAcuityExp_2017-07-13_14-39-17_VR-4A_NIC-Came...  [  0.   7.  14.  28.]
# 4  VRAcuityExp_2017-07-13_15-19-09_VR-2A_EDU-Came...  [  0.   7.  14.  28.]
# 5  VRAcuityExp_2017-07-13_15-53-40_VR-1B_NIC-Came...  [  0.   7.  14.  28.]
# 6  VRAcuityExp_2017-07-13_15-05-16_VR-2B_NIC-Came...  [  0.   7.  14.  28.]
# 7  VRAcuityExp_2017-07-13_15-38-34_VR-1A_NIC-Came...  [  0.   7.  14.  28.]

# %%
g = sns.FacetGrid(hue='session_id', data=dfratv, size=4, aspect=2)
g.map(sns.distplot, 'U');

# %%
dfratv['U'] = dfratv['U'].rolling(window=20, center=True).mean()

# %%
df = pd.merge(dfratv, dfevent, on=['Frame', 'session_id','Time'])


df['subU'] = df['speed'] - df['U'] 

g = sns.FacetGrid(data=df, size=4, aspect=2, hue='session_id')
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);

# %% [markdown]
# ## Experiment 0

# %%
dd0 = df[df['session_id']==0]

# %%
dfsession.video_name[0]
# Out:
# 'VRAcuityExp_2017-07-13_17-09-07_VR-5A_NIC-Camera 11136'

# %%
g = sns.FacetGrid(data=dd0, size=6, aspect=2)
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1, color='red');
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='green');
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);

# %%
## 81 - 83
dpart = dd0[(dd0['Time']>81.5) & (dd0['Time']<83.5)]
xmin, xmax = 82.5, 83

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
## 85 - 86
dpart = dd0[(dd0['Time']>84.5) & (dd0['Time']<87)]
xmin, xmax = 85, 86

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
## 110 - 111
dpart = dd0[(dd0['Time']>110) & (dd0['Time']<114)]
xmin, xmax = 110.5, 111.8

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
## 188 - 190
dpart = dd0[(dd0['Time']>190) & (dd0['Time']<195)]
xmin, xmax = 192.5, 194

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
## 226 - 228
dpart = dd0[(dd0['Time']>225.5) & (dd0['Time']<234)]
xmin, xmax = 226, 232

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
## 231, 232
dpart = dd0[(dd0['Time']>229) & (dd0['Time']<233)]
xmin, xmax = 230, 232

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %% [markdown]
# ## Experiment 1

# %%
dd1 = df[df['session_id']==1]

# %%
dfsession.video_name[1]
# Out:
# 'VRAcuityExp_2017-07-13_16-11-46_VR-3A_NIC-Camera 11136'

# %%
g = sns.FacetGrid(data=dd1, size=6, aspect=2)
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1, color='red');
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='green');
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);

# %%
## 78, 80
dpart = dd1[(dd1['Time']>76) & (dd1['Time']<81)]
xmin, xmax = 77, 80

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
## 180, 182; 183, 185
dpart = dd1[(dd1['Time']>181.5) & (dd1['Time']<183)]
xmin, xmax = 181.8, 182.6

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
## 197, 199
dpart = dd1[(dd1['Time']>196) & (dd1['Time']<200)]
xmin, xmax = 197, 199

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
## 212, 218
dpart = dd1[(dd1['Time']>213) & (dd1['Time']<219)]
xmin, xmax = 214, 217.8

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
## 221, 224
dpart = dd1[(dd1['Time']>220) & (dd1['Time']<227)]
xmin, xmax = 221, 224

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
## 372, 376
dpart = dd1[(dd1['Time']>370) & (dd1['Time']<386)]
xmin, xmax = 371, 376

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

xmin, xmax = 379, 385
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');

# %%
## 546, 548, 549, 550
dpart = dd1[(dd1['Time']>546) & (dd1['Time']<550)]
xmin, xmax = 547, 549

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
## 551, 553
dpart = dd1[(dd1['Time']>551.7) & (dd1['Time']<559.5)]
xmin, xmax = 552, 553

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

xmin, xmax = 556, 559
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
