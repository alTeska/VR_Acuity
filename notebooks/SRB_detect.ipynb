# %% [markdown]
# # SRB moments distributions dataset
# Notebook for collection and analysis of identified SRB events.

# %%
# data loading
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from scipy import stats, integrate

# %matplotlib inline
sns.set(color_codes=True)

path = '../datasets/preprocessed/'
dfrat     = pd.read_hdf(path+'relationalDatabase.h5', 'Rat_Behavior').set_index('index')
dfevent   = pd.read_hdf(path+'relationalDatabase.h5', 'Events').set_index('index')
dfsession = pd.read_hdf(path+'relationalDatabase.h5', 'Sessions')

dfratclean = pd.read_hdf(path+'filteredDatabase.h5', 'Rat_Behavior').set_index('index')
dfratv = pd.read_hdf(path+'velocityDatabase.h5', 'Rat_Behavior').set_index('index')

# %%
df = pd.merge(dfratv, dfevent, on=['Frame', 'session_id','Time'])
df['subU'] = df['speed'] - df['U'] 
df['subUM'] = df['speed'] - df['UM']

# %% [markdown]
# ## Experiment 2

# %%
dfSRB2 = pd.DataFrame()
dd2 = df[df['session_id']==2]

# %%
#  71, 73
dpart = dd2[(dd2['Time']>70) & (dd2['Time']<75)]
xmin, xmax = 71, 74

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "UM", alpha=1, linewidth=1, color='green');
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
# g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

g = sns.FacetGrid(data=dpart, size=6, aspect=2, ylim=[-30,30])
# g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subUM", alpha=1, linewidth=1, color='pink');
g.map(plt.plot, "Time", "UM", alpha=1, linewidth=1, color='green');
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
dpart2 = dd2[(dd2['Time']>xmin) & (dd2['Time']<xmax)]
dfSRB2 = pd.concat([dfSRB2, dpart2], axis=0, ignore_index=True)

# %%
## 247, 249
dpart = dd2[(dd2['Time']>240) & (dd2['Time']<250)]
xmin, xmax = 241, 249.5

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

g = sns.FacetGrid(data=dpart, size=6, aspect=2, ylim=[-30,30])
# g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subUM", alpha=1, linewidth=1, color='pink');
g.map(plt.plot, "Time", "UM", alpha=1, linewidth=1, color='green');
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
dpart2 = dd2[(dd2['Time']>xmin) & (dd2['Time']<xmax)]
dfSRB2 = pd.concat([dfSRB2, dpart2], axis=0, ignore_index=True)

# %%
## 315, 317
dpart = dd2[(dd2['Time']>313) & (dd2['Time']<320)]
xmin, xmax = 315, 318

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

g = sns.FacetGrid(data=dpart, size=6, aspect=2, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');
g.map(plt.axhline, y=-11.2, alpha=1, linewidth=1, color='pink');
g.map(plt.axhline, y=-16.8, alpha=1, linewidth=1, color='pink');

# %%
dpart2 = dd2[(dd2['Time']>xmin) & (dd2['Time']<xmax)]
dfSRB2 = pd.concat([dfSRB2, dpart2], axis=0, ignore_index=True)

# %%
## 351, 356
dpart = dd2[(dd2['Time']>350) & (dd2['Time']<358)]
xmin, xmax = 351.7, 355.5

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
dpart2 = dd2[(dd2['Time']>xmin) & (dd2['Time']<xmax)]
dfSRB2 = pd.concat([dfSRB2, dpart2], axis=0, ignore_index=True)

# %%
## 386, 388
dpart = dd2[(dd2['Time']>386) & (dd2['Time']<388.85)]
xmin, xmax = 386.3, 388.8

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
# g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
dpart2 = dd2[(dd2['Time']>xmin) & (dd2['Time']<xmax)]
dfSRB2 = pd.concat([dfSRB2, dpart2], axis=0, ignore_index=True)

# %%
## 402, 407
dpart = dd2[(dd2['Time']>402) & (dd2['Time']<409.1)]
xmin, xmax = 402.1, 409

g = sns.FacetGrid(data=dpart, size=6, aspect=2, ylim=[-30,80])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
# g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
dpart2 = dd2[(dd2['Time']>xmin) & (dd2['Time']<xmax)]
dfSRB2 = pd.concat([dfSRB2, dpart2], axis=0, ignore_index=True)

# %%
## 630, 632, 633, 634
dpart = dd2[(dd2['Time']>630) & (dd2['Time']<636)]
xmin, xmax = 630.2, 634

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
# g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');
g.map(plt.axhline, y=-33.6, alpha=1, linewidth=1, color='pink');
g.map(plt.axhline, y=-22.4, alpha=1, linewidth=1, color='pink');

# %%
dpart2 = dd2[(dd2['Time']>xmin) & (dd2['Time']<xmax)]
dfSRB2 = pd.concat([dfSRB2, dpart2], axis=0, ignore_index=True)

# %% [markdown]
# ## Experiment 4

# %%
dfSRB4 = pd.DataFrame()
dd4 = df[df['session_id']==4]

# %%
# 221, 228
dpart = dd4[(dd4['Time']>222.5) & (dd4['Time']<230)]
xmin, xmax = 222.7, 228

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
# g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "UM", alpha=1, linewidth=1, color='green');
# g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');

g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');
g.map(plt.axhline, y=-33.6, alpha=1, linewidth=1, color='pink');
g.map(plt.axhline, y=-22.4, alpha=1, linewidth=1, color='pink');

# %%
dpart4 = dd4[(dd4['Time']>xmin) & (dd4['Time']<xmax)]
dfSRB4 = pd.concat([dfSRB4, dpart4], axis=0, ignore_index=True)

# %%
# 267, 270
dpart = dd4[(dd4['Time']>265.8) & (dd4['Time']<272)]
xmin, xmax = 266, 271.6

g = sns.FacetGrid(data=dpart, size=6, aspect=2, ylim=[-50,50])
# g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
# g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.plot, "Time", "UM", alpha=1, linewidth=1, color='green');

g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');
g.map(plt.axhline, y=11.6, alpha=1, linewidth=1, color='pink');
g.map(plt.axhline, y=16.8, alpha=1, linewidth=1, color='pink');

# %%
dpart4 = dd4[(dd4['Time']>xmin) & (dd4['Time']<xmax)]
dfSRB4 = pd.concat([dfSRB4, dpart4], axis=0, ignore_index=True)

# %%
# 287, 291
dpart = dd4[(dd4['Time']>286.8) & (dd4['Time']<291.5)]
xmin, xmax = 287, 291

g = sns.FacetGrid(data=dpart, size=6, aspect=2)
# g.map(plt.plot, "Time", "U", alpha=1, linewidth=1);
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
g.map(plt.plot, "Time", "UM", alpha=1, linewidth=1, color='green');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');

g.map(plt.axhline, y=-11.6, alpha=1, linewidth=1, color='pink');
g.map(plt.axhline, y=-16.8, alpha=1, linewidth=1, color='pink');

# %%
dpart4 = dd4[(dd4['Time']>xmin) & (dd4['Time']<xmax)]
dfSRB4 = pd.concat([dfSRB4, dpart4], axis=0, ignore_index=True)

# %% [markdown]
# ## Experiment 5

# %%
dfSRB5 = pd.DataFrame()
dd5 = df[df['session_id']==5]

# %%
#  99, 104
dpart = dd5[(dd5['Time']>98.8) & (dd5['Time']<104)]
xmin, xmax = 99, 103.8

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "UM", alpha=1, linewidth=1, color='green');
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
# g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');
g.map(plt.axhline, y=8.4, alpha=1, linewidth=1, color='pink');
g.map(plt.axhline, y=5.6, alpha=1, linewidth=1, color='pink');

# %%
dpart5 = dd5[(dd5['Time']>xmin) & (dd5['Time']<xmax)]
dfSRB5 = pd.concat([dfSRB5, dpart5], axis=0, ignore_index=True)

# %%
# 155, 157
dpart = dd5[(dd5['Time']>155.5) & (dd5['Time']<158.2)]
xmin, xmax = 155.7, 158

g = sns.FacetGrid(data=dpart, size=6, aspect=2, ylim=[-15,20])
g.map(plt.plot, "Time", "UM", alpha=1, linewidth=1, color='green');
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
# g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');
g.map(plt.axhline, y=-8.4, alpha=1, linewidth=1, color='pink');
g.map(plt.axhline, y=-5.6, alpha=1, linewidth=1, color='pink');

# %%
dpart5 = dd5[(dd5['Time']>xmin) & (dd5['Time']<xmax)]
dfSRB5 = pd.concat([dfSRB5, dpart5], axis=0, ignore_index=True)

# %%
# 355, 365
dpart = dd5[(dd5['Time']>353.8) & (dd5['Time']<365.5)]
xmin, xmax = 354, 358

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "UM", alpha=1, linewidth=1, color='green');
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
# g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

g.map(plt.axhline, y=16.8, alpha=1, linewidth=1, color='pink');
g.map(plt.axhline, y=11.6, alpha=1, linewidth=1, color='pink');

dpart5 = dd5[(dd5['Time']>xmin) & (dd5['Time']<xmax)]
dfSRB5 = pd.concat([dfSRB5, dpart5], axis=0, ignore_index=True)

xmin, xmax = 361.4, 365
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');

dpart5 = dd5[(dd5['Time']>xmin) & (dd5['Time']<xmax)]
dfSRB5 = pd.concat([dfSRB5, dpart5], axis=0, ignore_index=True)

# %% [markdown]
# ## Experiment 6

# %%
dfSRB6 = pd.DataFrame()
dd6 = df[df['session_id']==6]

# %%
# 278, 279
dpart = dd6[(dd6['Time']>278) & (dd6['Time']<279.3)]
xmin, xmax = 278.1, 279

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "UM", alpha=1, linewidth=1, color='green');
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
# g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

g.map(plt.axhline, y=16.8, alpha=1, linewidth=1, color='pink');
g.map(plt.axhline, y=11.6, alpha=1, linewidth=1, color='pink');

# %%
dpart6 = dd6[(dd6['Time']>xmin) & (dd6['Time']<xmax)]
dfSRB6 = pd.concat([dfSRB6, dpart6], axis=0, ignore_index=True)

# %%
# 281, 283
dpart = dd6[(dd6['Time']>283.1) & (dd6['Time']<288)]
xmin, xmax = 283.2, 287.5

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "UM", alpha=1, linewidth=1, color='green');
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
# g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');

g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');
g.map(plt.axhline, y=16.8, alpha=1, linewidth=1, color='pink');
g.map(plt.axhline, y=11.2, alpha=1, linewidth=1, color='pink');

# %%
dpart6 = dd6[(dd6['Time']>xmin) & (dd6['Time']<xmax)]
dfSRB6 = pd.concat([dfSRB6, dpart6], axis=0, ignore_index=True)

# %%
# 305, 310
dpart = dd6[(dd6['Time']>305) & (dd6['Time']<310.1)]
xmin, xmax = 305.5, 310.15

g = sns.FacetGrid(data=dpart, size=6, aspect=2, ylim=[-20,80])
g.map(plt.plot, "Time", "UM", alpha=1, linewidth=1, color='green');
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
# g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

g.map(plt.axhline, y=-16.8, alpha=1, linewidth=1, color='pink');
g.map(plt.axhline, y=-11.2, alpha=1, linewidth=1, color='pink');

# %%
dpart6 = dd6[(dd6['Time']>xmin) & (dd6['Time']<xmax)]
dfSRB6 = pd.concat([dfSRB6, dpart6], axis=0, ignore_index=True)

# %% [markdown]
# ## Experiment 7

# %%
dfSRB7 = pd.DataFrame()
dd7 = df[df['session_id']==7]

# %%
# 71, 73
dpart = dd7[(dd7['Time']>72) & (dd7['Time']<73)]
xmin, xmax = 72.2, 72.9

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "UM", alpha=1, linewidth=1, color='green');
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
# g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
dpart7 = dd7[(dd7['Time']>xmin) & (dd7['Time']<xmax)]
dfSRB7 = pd.concat([dfSRB7, dpart7], axis=0, ignore_index=True)

# %%
# 157, 159
dpart = dd7[(dd7['Time']>157.15) & (dd7['Time']<158.75)]
xmin, xmax = 157.2, 158.7

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "UM", alpha=1, linewidth=1, color='green');
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
# g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
dpart7 = dd7[(dd7['Time']>xmin) & (dd7['Time']<xmax)]
dfSRB7 = pd.concat([dfSRB7, dpart7], axis=0, ignore_index=True)

# %%
# 225, 230
dpart = dd7[(dd7['Time']>225.5) & (dd7['Time']<230)]
xmin, xmax = 226, 229.85

g = sns.FacetGrid(data=dpart, size=6, aspect=2)#, ylim=[-30,30])
g.map(plt.plot, "Time", "UM", alpha=1, linewidth=1, color='green');
g.map(plt.plot, "Time", "speed" , alpha=1, linewidth=1);
# g.map(plt.plot, "Time", "subU", alpha=1, linewidth=1, color='pink');
g.map(plt.axvline, x=xmin, alpha=1, linewidth=1, color='red');
g.map(plt.axvline, x=xmax, alpha=1, linewidth=1, color='red');
g.map(plt.axhline, y=0, alpha=1, linewidth=1, color='green');

# %%
dpart7 = dd7[(dd7['Time']>xmin) & (dd7['Time']<xmax)]
dfSRB5 = pd.concat([dfSRB7, dpart7], axis=0, ignore_index=True)

# %% [markdown]
# ## Experiments combined - visualization

# %%
dfSRB = pd.DataFrame()
dfSRB = pd.concat([dfSRB, dfSRB2], axis=0, ignore_index=True)
dfSRB = pd.concat([dfSRB, dfSRB4], axis=0, ignore_index=True)
dfSRB = pd.concat([dfSRB, dfSRB5], axis=0, ignore_index=True)
dfSRB = pd.concat([dfSRB, dfSRB6], axis=0, ignore_index=True)
dfSRB = pd.concat([dfSRB, dfSRB7], axis=0, ignore_index=True)

# %%
dfSRB.head()
# Out:
#    Frame       Time     X_Pos     Y_Pos     Z_Pos     X_Ori     Y_Ori  \
# 0  17040  71.000005  0.072614  0.095443 -0.038461  0.943414 -0.267464
# 1  17041  71.004171  0.072631  0.095450 -0.038446  0.943570 -0.267228
# 2  17042  71.008338  0.072648  0.095457 -0.038431  0.943722 -0.267010
# 3  17043  71.012505  0.072666  0.095464 -0.038417  0.943887 -0.266747
# 4  17044  71.016671  0.072677  0.095470 -0.038406  0.944003 -0.266652
#
#       Z_Ori  session_id        dT    ...          lz2  clockwise     theta  \
# 0 -0.195232           2  0.004167    ...    -0.203123         -1  0.000485
# 1 -0.194803           2  0.004166    ...    -0.202648         -1  0.000469
# 2 -0.194368           2  0.004167    ...    -0.202189         -1  0.000474
# 3 -0.193931           2  0.004167    ...    -0.201725         -1  0.000479
# 4 -0.193512           2  0.004166    ...    -0.201255         -1  0.000449
#
#           U        UM  MotiveExpTimeSecs  visible  speed      subU     subUM
# 0 -6.662978 -6.376508          59.129167        1   -7.0 -0.337022 -0.623492
# 1 -6.446231 -6.361802          59.129167        1   -7.0 -0.553769 -0.638198
# 2 -6.523562 -6.319288          59.129167        1   -7.0 -0.476438 -0.680712
# 3 -6.586125 -6.263810          59.129167        1   -7.0 -0.413875 -0.736190
# 4 -6.177022 -6.187017          59.129167        1   -7.0 -0.822978 -0.812983
#
# [5 rows x 25 columns]

# %%
len(dfSRB) * 100/ len(dfratv)
# Out:
# 1.9879682513018646

# %%
l, lsrb = {}, {}
for i, dd in dfratv.groupby('session_id'):
    l[i] = len(dd) 
    
for i, dd in dfSRB.groupby('session_id'):
    print(i, len(dd) * 100/l[i])
# Out:
# 2 6.723518282139721
# 4 3.9182756344178182
# 6 2.2943176299174355
# 7 2.6017116524028965

# %%
g = sns.FacetGrid(hue='session_id', data=dfSRB, size=4, aspect=2)
g.map(sns.distplot, 'U');

g = sns.FacetGrid(hue='session_id', data=dfSRB, size=4, aspect=2)
g.map(sns.distplot, 'UM');

# %%
g = sns.FacetGrid( data=dfSRB, size=8, aspect=2, xlim=[-50,50], hue='speed')
g.map(plt.scatter,'U', "Y_Pos", alpha=0.8, s=1);

g = sns.FacetGrid( data=dfSRB, size=8, aspect=2, xlim=[-50,50], hue='speed')
g.map(sns.distplot, 'U');

# %%
# postiion distribution visualization 
g = sns.FacetGrid(hue='session_id', data=dfSRB, size=4, aspect=2)
g.map(sns.distplot, 'Y_Pos');

# oritentation distribution visualization 
g = sns.FacetGrid(hue='session_id', data=dfSRB, size=4, aspect=2)
g.map(sns.distplot, 'Y_Ori');

# scatter between orientation and position
g = sns.FacetGrid( data=dfSRB, size=4, aspect=2, hue='session_id')
g.map(plt.scatter, "Y_Pos", "Y_Ori", alpha=0.1, s=0.1);

# %%
sns.pairplot(dfSRB, vars=['X_Pos', 'Y_Pos', 'Z_Pos'], plot_kws={"s": 3}, hue='session_id');

# %%
sns.pairplot(dfSRB, vars=['X_Ori', 'Y_Ori', 'Z_Ori'], plot_kws={"s": 3}, hue='session_id');

# %%
import datashader as ds
from matplotlib import rcParams, cm

# %%
cvs = ds.Canvas(plot_height=900, plot_width=900)
agg_z =cvs.points(source=dfSRB, x='X_Pos', y='Z_Pos', agg=ds.mean('Z_Ori'))
agg_x =cvs.points(source=dfSRB, x='X_Pos', y='Z_Pos', agg=ds.mean('X_Ori'))


# np.linalg.norm(agg)
agg_xn = agg_x / np.sqrt(agg_x ** 2 + agg_z ** 2)
agg_zn = agg_z / np.sqrt(agg_x ** 2 + agg_z ** 2)

theta = np.arctan2(agg_zn, agg_xn)

cm.hsv.set_bad('black')
plt.figure(figsize=(10, 10))
plt.imshow(theta, cmap=cm.hsv)

plt.colorbar()

# %% [markdown]
# ## SRB application attempt
# 0. define threshold 0
# 1. Find SRB of threshold zero
# 2. check dT in between them
# 3. if dT bigger then resolution of experiment smaller then X
# 4. check trsehold 2

# %%
dfSRB.head()
# Out:
#    Frame       Time     X_Pos     Y_Pos     Z_Pos     X_Ori     Y_Ori  \
# 0  17040  71.000005  0.072614  0.095443 -0.038461  0.943414 -0.267464
# 1  17041  71.004171  0.072631  0.095450 -0.038446  0.943570 -0.267228
# 2  17042  71.008338  0.072648  0.095457 -0.038431  0.943722 -0.267010
# 3  17043  71.012505  0.072666  0.095464 -0.038417  0.943887 -0.266747
# 4  17044  71.016671  0.072677  0.095470 -0.038406  0.944003 -0.266652
#
#       Z_Ori  session_id        dT  ...    clockwise     theta         U  \
# 0 -0.195232           2  0.004167  ...           -1  0.000485 -6.662978
# 1 -0.194803           2  0.004166  ...           -1  0.000469 -6.446231
# 2 -0.194368           2  0.004167  ...           -1  0.000474 -6.523562
# 3 -0.193931           2  0.004167  ...           -1  0.000479 -6.586125
# 4 -0.193512           2  0.004166  ...           -1  0.000449 -6.177022
#
#          UM  MotiveExpTimeSecs  visible  speed      subU     subUM  dtime
# 0 -6.376508          59.129167        1   -7.0 -0.337022 -0.623492    NaN
# 1 -6.361802          59.129167        1   -7.0 -0.553769 -0.638198    NaN
# 2 -6.319288          59.129167        1   -7.0 -0.476438 -0.680712    NaN
# 3 -6.263810          59.129167        1   -7.0 -0.413875 -0.736190    NaN
# 4 -6.187017          59.129167        1   -7.0 -0.822978 -0.812983    NaN
#
# [5 rows x 26 columns]

# %%
dfSRB['dtime'] = dfSRB['Time'].diff(1)
dfSRB.dtime
# Out:
# 10811         NaN
# 10812    0.004167
# 10813    0.004167
# 10814    0.004166
# 10815    0.004167
# 10816    0.004167
# 10817    0.004166
# 10818    0.004167
# 10819    0.004167
# 10820    0.004166
# 10821    0.004167
# 10822    0.004167
# 10823    0.004166
# 10824    0.004167
# 10825    0.004167
# 10826    0.004166
# 10827    0.004167
# 10828    0.004167
# 10829    0.004166
# 10830    0.004167
# 10831    0.004167
# 10832    0.004166
# 10833    0.004167
# 10834    0.004167
# 10835    0.004166
# 10836    0.004167
# 10837    0.004167
# 10838    0.004166
# 10839    0.004167
# 10840    0.004167
#            ...
# 15118    0.004167
# 15119    0.004167
# 15120    0.004166
# 15121    0.004167
# 15122    0.004167
# 15123    0.004166
# 15124    0.004167
# 15125    0.004167
# 15126    0.004166
# 15127    0.004167
# 15128    0.004167
# 15129    0.004166
# 15130    0.004167
# 15131    0.004167
# 15132    0.004166
# 15133    0.004167
# 15134    0.004167
# 15135    0.004166
# 15136    0.004167
# 15137    0.004167
# 15138    0.004166
# 15139    0.004167
# 15140    0.004167
# 15141    0.004166
# 15142    0.004167
# 15143    0.004167
# 15144    0.004166
# 15145    0.004167
# 15146    0.004167
# 15147    0.004166
# Name: dtime, Length: 1975, dtype: float64

# %%
dfSRB.head()
# Out:
#        Frame       Time     X_Pos     Y_Pos     Z_Pos     X_Ori     Y_Ori  \
# 10811  17329  72.204171  0.002166  0.099827  0.068060 -0.035761 -0.057798
# 10812  17330  72.208338  0.002119  0.099825  0.068061 -0.036647 -0.058029
# 10813  17331  72.212505  0.002071  0.099822  0.068059 -0.037493 -0.058311
# 10814  17332  72.216671  0.002024  0.099819  0.068056 -0.038313 -0.058639
# 10815  17333  72.220838  0.001976  0.099815  0.068054 -0.039149 -0.058926
#
#           Z_Ori  session_id        dT    ...     clockwise     theta  \
# 10811  0.997434           7  0.004166    ...            -1  0.000839
# 10812  0.997388           7  0.004167    ...            -1  0.000889
# 10813  0.997341           7  0.004167    ...            -1  0.000848
# 10814  0.997291           7  0.004166    ...            -1  0.000823
# 10815  0.997242           7  0.004167    ...            -1  0.000839
#
#                U         UM  MotiveExpTimeSecs  visible  speed       subU  \
# 10811 -11.540101 -11.417556          58.804167        1  -28.0 -16.459899
# 10812 -12.230178 -11.438255          58.804167        1  -28.0 -15.769822
# 10813 -11.664497 -11.456868          58.804167        1  -28.0 -16.335503
# 10814 -11.316994 -11.478388          58.804167        1  -28.0 -16.683006
# 10815 -11.532118 -11.492961          58.804167        1  -28.0 -16.467882
#
#            subUM     dtime
# 10811 -16.582444       NaN
# 10812 -16.561745  0.004167
# 10813 -16.543132  0.004167
# 10814 -16.521612  0.004166
# 10815 -16.507039  0.004167
#
# [5 rows x 26 columns]

# %%
dfSRB.dropna(inplace=True)
g = sns.FacetGrid(hue='session_id', data=dfSRB, size=4, aspect=2)
g.map(sns.distplot, 'dtime');

# %%
g = sns.FacetGrid(hue='session_id', data=dfSRB, size=8, aspect=2, hue_order=[6,7])
g.map(plt.scatter, 'Time', 'subU', alpha=1, s=1);
g = sns.FacetGrid(hue='session_id', data=dfSRB, size=8, aspect=2, hue_order=[6,7])
g.map(plt.scatter, 'Time','dtime', alpha=1, s=1);
g = sns.FacetGrid(hue='session_id', data=dfSRB, size=8, aspect=2, hue_order=[6,7])
g.map(plt.scatter, 'dtime', 'subU', alpha=1, s=5);
