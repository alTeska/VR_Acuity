# %% [markdown]
# # Data distribution analysis
#
# Notebook for analysis of data distribution.

# %% [markdown]
# ## Loading the datasets

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(color_codes=True)

dfOri, dfPos = {}, {}

fnameClean = [
    'VRAcuityExp_2017-07-13_14-39-17_VR-4A_NIC_clean.h5',
    'VRAcuityExp_2017-07-13_15-05-16_VR-2B_NIC_clean.h5',
    'VRAcuityExp_2017-07-13_15-19-09_VR-2A_EDU_clean.h5',
    'VRAcuityExp_2017-07-13_15-38-34_VR-1A_NIC_clean.h5',
    'VRAcuityExp_2017-07-13_15-53-40_VR-1B_NIC_clean.h5',
    'VRAcuityExp_2017-07-13_16-11-46_VR-3A_NIC_clean.h5',
    'VRAcuityExp_2017-07-13_16-27-08_VR-3A_NIC_clean.h5',
    'VRAcuityExp_2017-07-13_17-09-07_VR-5A_NIC_clean.h5', ]

path = '../datasets/'

#cleaned data loading
for i, x in enumerate(fnameClean):
    dfOri[i] = pd.read_hdf(path+fnameClean[i], 'Orientation')
    dfPos[i] = pd.read_hdf(path+fnameClean[i], 'Position')

# %% [markdown]
# ## Position - Distributions of X, Y, Z for one experiment

# %%
# Univariate distributions
df = dfPos[1]
fig = plt.figure(figsize=(9,9))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

sns.distplot(df.X, ax=ax1)
sns.distplot(df.Y, ax=ax2)
sns.distplot(df.Z, ax=ax3)

# %%
# bivariate distributions
sns.jointplot(x="X", y="Z", data=df);

# %%
fig = plt.figure(figsize=(12,12))
sns.pairplot(df, vars=['X', 'Y', 'Z'])

# %% [markdown]
# ## Position - distributions of X, Y, Z comparison for all experiments

# %%
# Univariat positions X,Y,Z of all experiments
fig = plt.figure(figsize=(9,12))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)
    
for i, x in enumerate(fnameClean):
    sns.distplot(dfPos[i].X, ax=ax1)
    sns.distplot(dfPos[i].Y, ax=ax2)
    sns.distplot(dfPos[i].Z, ax=ax3)

# %% [markdown]
# ## Orientation - distributions of X, Y, Z for one experiment

# %%
df = dfOri[1]

# Univariate distributions
fig = plt.figure(figsize=(9,9))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

sns.distplot(df.X, ax=ax1)
sns.distplot(df.Y, ax=ax2)
sns.distplot(df.Z, ax=ax3)

# %%
# bivariate distributions
sns.jointplot(x="X", y="Z", data=df);

# %%
fig = plt.figure(figsize=(12,12))
sns.pairplot(df, vars=['X', 'Y', 'Z'])

# %% [markdown]
# ## Orientation - distributions of X, Y, Z comparison for all experiments

# %%
# Univariat orientation X,Y,Z of all experiments
fig = plt.figure(figsize=(9,12))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)
    
for i, x in enumerate(fnameClean):
    sns.distplot(dfOri[i].X, ax=ax1)
    sns.distplot(dfOri[i].Y, ax=ax2)
    sns.distplot(dfOri[i].Z, ax=ax3)
